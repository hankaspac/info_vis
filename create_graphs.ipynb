# %%
import altair as alt
import pandas as pd
import json
import numpy as np
import vegafusion as vf
import networkx as nx
import nx_altair as nxa
import matplotlib as plt

# %%
# alt.data_transformers.disable_max_rows()
# vf.enable(row_limit=1000000)
alt.data_transformers.enable('default', max_rows=None)
# Out:
# DataTransformerRegistry.enable('default')

# %%
f = open('graph_nodes.json', 'r')
my_chart2 = json.load(f)
print(type(my_chart2))

#G = nx.readwrite.json_graph.node_link_graph(my_chart2, directed=True, multigraph=False)

#nxa.draw_networkx(G, node_tooltip=['title_without_series'])
# Out:
# <class 'list'>

# %%
# pos = nx.spring_layout(G) # Define the layout for node positioning
# nx.draw(G, pos, with_labels=True, node_size=300, node_color='skyblue', font_size=10, font_color='black')
# # Display the graph
# plt.show()
my_chart2
# Out:
# [{'text_reviews_count': '7',
#   'series': ['189911'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': 'B00071IKUY',
#   'average_rating': '4.03',
#   'similar_books': [19997,
#    828466,
#    1569323,
#    425389,
#    1176674,
#    262740,
#    3743837,
#    880461,
#    2292726,
#    1883810,
#    1808197,
#    625150,
#    1988046,
#    390170,
#    2620131,
#    383106,
#    1597281],
#   'description': 'Omnibus book club edition containing the Ladies of Madrigyn and the Witches of Wenshar.',
#   'format': 'Hardcover',
#   'authors': [{'author_id': '10333', 'role': ''}],
#   'publisher': 'Nelson Doubleday, Inc.',
#   'num_pages': '600',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': 'Book Club Edition',
#   'publication_year': '1987',
#   'book_id': 7327624,
#   'ratings_count': '140',
#   'work_id': '8948723',
#   'title_without_series': 'The Unschooled Wizard (Sun Wolf and Starhawk, #1-2)'},
#  {'text_reviews_count': '6',
#   'series': ['151854'],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '4.22',
#   'similar_books': [948696,
#    439885,
#    274955,
#    12978730,
#    372986,
#    2167631,
#    566784,
#    503322],
#   'description': "To Kara's astonishment, she discovers that a portal has opened in her bedroom closet and two goblins have fallen through! They refuse to return to the fairy realms and be drafted for an impending war. In an attempt to roust the pesky creatures, Kara falls through the portal, smack into the middle of a huge war. Kara meets Queen Selinda, who appoints Kara as a Fairy Princess and assigns her an impossible task: to put an end to the war using her diplomatic skills.\nAll's Fairy In Love And War is the eighth book in Avalon: Web of Magic, a twelve-book fantasy series for middle grade readers. Through their magical journey, the teenage heroines discover who they really are . . . and run into plenty of good guys, bad guys, and cute guys. Out of print for two years, Seven Seas is pleased to return the Avalon series to print in editions targeted for today's readers, with new manga-style covers and interior illustrations.",
#   'format': 'Paperback',
#   'authors': [{'author_id': '19158', 'role': ''}],
#   'publisher': 'Seven Seas',
#   'num_pages': '216',
#   'publication_day': '3',
#   'publication_month': '3',
#   'edition_information': '',
#   'publication_year': '2009',
#   'book_id': 6066812,
#   'ratings_count': '98',
#   'work_id': '701117',
#   'title_without_series': "All's Fairy in Love and War (Avalon: Web of Magic, #8)"},
#  {'text_reviews_count': '60',
#   'series': ['1052227'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': 'B01NCIKAQX',
#   'average_rating': '4.33',
#   'similar_books': [],
#   'description': '',
#   'format': '',
#   'authors': [{'author_id': '242185', 'role': ''}],
#   'publisher': '',
#   'num_pages': '318',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 33394837,
#   'ratings_count': '269',
#   'work_id': '54143148',
#   'title_without_series': "The House of Memory (Pluto's Snitch #2)"},
#  {'text_reviews_count': '1',
#   'series': ['147734'],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': 'B0056A00P4',
#   'average_rating': '4.04',
#   'similar_books': [519546, 1295074, 21407416],
#   'description': "This is the final tale in the bestselling author L.J. Smith's romantic horrortrilogy. Now, Kaitlyn Fairchild and her friends must put the powerful crystalto the test--to stop an experiment that has turned one of them into a psychicvampire. Kaitlyn must choose at last--Rob or Gabriel.",
#   'format': '',
#   'authors': [{'author_id': '50873', 'role': ''},
#    {'author_id': '232533', 'role': 'Ubersetzer'}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 12182387,
#   'ratings_count': '4',
#   'work_id': '285263',
#   'title_without_series': 'The Passion (Dark Visions, #3)'},
#  {'text_reviews_count': '21',
#   'series': ['811663'],
#   'country_code': 'US',
#   'language_code': 'en-US',
#   'asin': 'B01BLJGA9S',
#   'average_rating': '4.23',
#   'similar_books': [25515353,
#    20483269,
#    25650829,
#    18913492,
#    22578299,
#    25781561,
#    29518816,
#    20958132,
#    21854392,
#    27505924,
#    25205453],
#   'description': '',
#   'format': '',
#   'authors': [{'author_id': '5360266', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 29074693,
#   'ratings_count': '149',
#   'work_id': '46079519',
#   'title_without_series': "Prowled Darkness (Dante's Circle, #7)"},
#  {'text_reviews_count': '1',
#   'series': [],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': 'B00NLXQ534',
#   'average_rating': '4.12',
#   'similar_books': [25653153,
#    25699172,
#    23530486,
#    12984185,
#    25538377,
#    23525552,
#    18215952,
#    21412122,
#    25758901],
#   'description': 'Lillian Ann Cross is forced to live the worst nightmare of her life. She is an everyday middle class American, striving to survive in an everyday changing world. Her life was abruptly\nturned upsidedown forever as she was kidnapped and forced into a world called "Hen Fighting."\nA world in which women fight and bets are made upon their bloodshed.Lillian is forced to comply due to the threats made upon her mother\'s life. Being a loving person her whole life, Lillian finds difficulty grasping her new functions. As she is conditioned to live in her new world, she is subjected to an experimental procedure. A procedure which has taken the lives of a few before her. As she survives, she now has to learn how to live with her new "implants." Implants which strengthen her bones, giving her strength and an upper ability amongst others. Implants which require weekly sustenance, or she will die.',
#   'format': '',
#   'authors': [{'author_id': '8551671', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 25742454,
#   'ratings_count': '1',
#   'work_id': '42749946',
#   'title_without_series': 'The Switchblade Mamma'},
#  {'text_reviews_count': '27',
#   'series': ['938303'],
#   'country_code': 'US',
#   'language_code': 'en-GB',
#   'asin': 'B01HX6PENG',
#   'average_rating': '4.31',
#   'similar_books': [],
#   'description': "In the Finding Fatherhood series, these shifters become daddies in unconventional ways.\nCougar-shifter Jackson Sperry rescues Hannah from the ocean, and she has no memory of how she ended up floating in the Pacific. She also doesn't remember who she is or how she came to be pregnant. He's drawn to her and determined to protect her as they unravel the mystery of her past. It isn't long before he's ready to claim her as his mate and raise her son as his own--but without knowing the details of her past, the future remains uncertain, and he fears someone is still hunting Hannah and her baby.",
#   'format': '',
#   'authors': [{'author_id': '90411', 'role': ''},
#    {'author_id': '14356708', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 30838933,
#   'ratings_count': '139',
#   'work_id': '51437308',
#   'title_without_series': 'Guardian Cougar (Finding Fatherhood, #2)'},
#  {'text_reviews_count': '1',
#   'series': ['584334'],
#   'country_code': 'US',
#   'language_code': 'en-US',
#   'asin': 'B00HWK35OY',
#   'average_rating': '3.79',
#   'similar_books': [22044544,
#    23694100,
#    18243587,
#    13542030,
#    26208028,
#    22602755,
#    19503430,
#    27238427,
#    17969425,
#    19178976,
#    22449717,
#    23007497,
#    25712860,
#    24703884,
#    24927961,
#    18761510],
#   'description': "Maverick's story.",
#   'format': '',
#   'authors': [{'author_id': '3330668', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 20566082,
#   'ratings_count': '53',
#   'work_id': '32222419',
#   'title_without_series': "A Kitty in the Lion's Den (Sweet Water, #3)"},
#  {'text_reviews_count': '17',
#   'series': ['493993'],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '3.80',
#   'similar_books': [15728807,
#    17182499,
#    15673520,
#    16081758,
#    17842040,
#    17617648,
#    17934493,
#    18599667,
#    18302133,
#    17910091,
#    17675386,
#    17668473,
#    17334538,
#    18667948,
#    18528430,
#    15715844,
#    16059442,
#    15801763],
#   'description': "Wanted by no one.\nHunted by everyone.\nSixteen-year-old Nathan lives in a cage: beaten, shackled, trained to kill. In a modern-day England where two warring factions of witches live amongst humans, Nathan is an abomination, the illegitimate son of the world's most terrifying and violent witch, Marcus. Nathan's only hope for survival is to escape his captors, track down Marcus, and receive the three gifts that will bring him into his own magical powers--before it's too late. But how can Nathan find his father when there is no one safe to trust, not even family, not even the girl he loves?\nHalf Badis an international sensation and the start of a brilliant trilogy: a gripping tale of alienation and the indomitable will to survive.",
#   'format': 'ebook',
#   'authors': [{'author_id': '7314532', 'role': ''}],
#   'publisher': "Viking Children's",
#   'num_pages': '416',
#   'publication_day': '4',
#   'publication_month': '3',
#   'edition_information': '',
#   'publication_year': '2014',
#   'book_id': 21401181,
#   'ratings_count': '33',
#   'work_id': '24802827',
#   'title_without_series': 'Half Bad (Half Life, #1)'},
#  {'text_reviews_count': '19',
#   'series': ['152366'],
#   'country_code': 'US',
#   'language_code': 'en-US',
#   'asin': '',
#   'average_rating': '3.43',
#   'similar_books': [638556,
#    10647307,
#    405587,
#    436297,
#    1930388,
#    105501,
#    1415383,
#    16104804,
#    1146575,
#    664653,
#    6376953,
#    1142883,
#    7117330,
#    530877,
#    18509606,
#    772079,
#    18070915,
#    1425512],
#   'description': '',
#   'format': '',
#   'authors': [{'author_id': '41194', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 780918,
#   'ratings_count': '148',
#   'work_id': '766939',
#   'title_without_series': 'Rite of Conquest (William the Conqueror, #1)'},
#  {'text_reviews_count': '11',
#   'series': ['709800'],
#   'country_code': 'US',
#   'language_code': 'en-US',
#   'asin': 'B00Q2DWV4M',
#   'average_rating': '3.75',
#   'similar_books': [15738275,
#    23557009,
#    17225973,
#    15750539,
#    23996345,
#    13410858,
#    23509532,
#    15725683,
#    22056858,
#    23293899,
#    20949528,
#    22028924,
#    30171492,
#    17452636,
#    6998871,
#    15723789,
#    6759884,
#    30319563],
#   'description': "Marius believes himself to be an ordinary small-town apothecary - until the imperial guards show up at his door. Then he learns the truth: he is cousin to the Kjallan emperor. Before he was born, his mother eloped with her beloved, leaving the palace and its intrigues behind. Now Marius returns to the imperial seat, where he will learn healing magic and struggle to adapt his small town soul to big city life.\nMeanwhile, the neighboring nation of Sardos has collapsed, and refugees are pouring over the border. Isolda, a Sardossian shopkeeper, is among them.She has fled her cruel husband and now ekes out a living on the streets of the imperial city.\nWhen Marius meets Isolda in the aftermath of a factory explosion, he falls for this determined woman who, like him, is far from home and struggling to find her place. But Isolda faces daily discrimination and harassment, while Marius's imperial relatives parade before him a bevy of women they deem more suitable to his station. Marius must decide: is he the emperor's dutiful cousin, grateful for the gifts that have been given him, or is he his mother's son, prepared to sacrifice everything for love?",
#   'format': 'Kindle Edition',
#   'authors': [{'author_id': '6462472', 'role': ''}],
#   'publisher': 'Amy Raby',
#   'num_pages': '279',
#   'publication_day': '23',
#   'publication_month': '11',
#   'edition_information': '1st Edition',
#   'publication_year': '2014',
#   'book_id': 23615331,
#   'ratings_count': '112',
#   'work_id': '43219002',
#   'title_without_series': "Healer's Touch (Hearts And Thrones, #4)"},
#  {'text_reviews_count': '9',
#   'series': ['176160'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': 'B0042JSOQC',
#   'average_rating': '4.35',
#   'similar_books': [25861113,
#    7430195,
#    18765937,
#    6120544,
#    3247550,
#    9266753,
#    6976966,
#    25764778,
#    17696585,
#    23256849,
#    642463,
#    2842796,
#    263172,
#    10874337],
#   'description': "It all comes down to this.\nVlad's running out of time. The Elysian Council has given him weeks to live, and that's if the Slayer Society doesn't kill him - along with all the citizens of Bathory - first. Then there's the issue of Vlad's father, who may or may not still be alive after all these years, and oh yeah, that tiny little detail in the Pravus prophecy about Vlad enslaving Vampirekind and the human race. So much for college applications.\nIn this epic finale to Heather Brewer's heart-stopping Chronicles of Vladimir Tod, dark secrets will be revealed, old friends will become enemies, and warm blood will run cold. Just be careful it isn't yours.",
#   'format': '',
#   'authors': [{'author_id': '293603', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 10099492,
#   'ratings_count': '152',
#   'work_id': '10800440',
#   'title_without_series': 'Twelfth Grade Kills (The Chronicles of Vladimir Tod, #5)'},
#  {'text_reviews_count': '54',
#   'series': ['152365'],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '3.49',
#   'similar_books': [1616595,
#    2356304,
#    5432871,
#    9766146,
#    6058757,
#    357264,
#    428798,
#    1306752,
#    1492132,
#    9069880,
#    7564251,
#    450449,
#    2262259,
#    6314293,
#    1753606,
#    1896805,
#    1553844,
#    7143298],
#   'description': "The beautiful Averil is heir to the Duchy of Quitaine, in the Kingdom of Lys. She is a powerful mage, trained by the Ladies of the Isle, but when her father calls her home to take up her duties, she must leave that life behind. In her city of Fontevrai, she meets Gereint, raised as a common villager but greatly gifted in magic, a novice of the magical order of the Knights of the Rose.\nThe Knights and their sister order, the Ladies of the Isle, defend a great secret: the means and location of the Serpent's imprisonment a thousand years ago by the Young God in whose name their order was founded.\nQuitaine is under subtle attack by the King of Lys, who has secretly become an adept of the hidden order of the Serpent, and he will let nothing and no one stand in the way of his quest to discover how to free his God. But the Knights of the Rose, and the Ladies of the Isle believe that if the Serpent is freed, the world will be enslaved to chaos: humanity will destroy itself, and all that man has made will be corrupted.\nThe War of the Rose and Serpent has begun again, after a thousand years.",
#   'format': 'Paperback',
#   'authors': [{'author_id': '410348', 'role': ''}],
#   'publisher': 'Tor Books',
#   'num_pages': '320',
#   'publication_day': '6',
#   'publication_month': '3',
#   'edition_information': '',
#   'publication_year': '2007',
#   'book_id': 780917,
#   'ratings_count': '372',
#   'work_id': '766938',
#   'title_without_series': 'The Serpent and the Rose (War of the Rose, #1)'},
#  {'text_reviews_count': '4',
#   'series': ['975829'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': 'B013FJE4XG',
#   'average_rating': '3.75',
#   'similar_books': [],
#   'description': "So...yeah. It's me again. America's most sarcastic vampire.\nI'm back on the blog. It's been a while - about a year, if we need to get into specifics. Which I usually do. It's just a thing with me.\nA lot has happened since we last chatted - some good, some bad. All worthwhile, in the grand scheme. I've dealt with the whole Living Dead thing long enough now to know how to keep it from taking over my life. What I'm still figuring out is how to keep it from wreaking havoc on everyone else's lives. It's a roller coaster, for sure, but I'm convinced that waiting for me somewhere on the other side of the Other Side is a real-life life, not just some artificially-sweetened half-life substitute. I want a family. I want my music.\nI want the dream come true, not the dream fell through.\nAnd I'm determined to have it, regardless of how eternal this afterlife thing might be. But it's a hell of a lot to keep track of. Barring any unforeseen developments that might undo all my vampirosity, I may have to grow up a little in order to get it all to work out. I'm ready for that, though.\nAs fun as it might seem to hang with the Lost Boys, I can't be Peter Pan-pire forever.",
#   'format': '',
#   'authors': [{'author_id': '5757470', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 26096065,
#   'ratings_count': '28',
#   'work_id': '23974920',
#   'title_without_series': 'The Afterlife (Joe Vampire, #2)'},
#  {'text_reviews_count': '4',
#   'series': ['627799'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': 'B00FNB0FA6',
#   'average_rating': '3.77',
#   'similar_books': [25728789,
#    17931030,
#    20604089,
#    20499538,
#    18459991,
#    18731770,
#    15765627,
#    18516963,
#    19291146,
#    13506878,
#    18243476,
#    13178363,
#    17620123,
#    20751421,
#    23245396,
#    17618111],
#   'description': "This contains all SIX novels and two shorts of the Blood & Light Vampire Series.\nBlood & Light (book #1)\nSmoke & Mirrors (book #2)\nOil & Water (book #3)\nClarity & Reason (book #4\nGrace & Beauty (book #5)\nHope & Faith (book #6)\nPLUS two bonus shorts\nBirth of a Vampire\nWill and Wonder\nRue lives in the quiet little town of Calvary, Minnesota with her brother Kai, and her parents, Grace and William. Calvary is a beautiful place, with no crime, no drama and nestled along the great lakes. It is surrounded in lush forests, quiet, safe, everything you could ever wish for...or is it?\nAs Rue approaches her 17th birthday she is plagued with one problem, a very big one. Her Mother, Grace, has fallen ill. It is not a disease that can easily be fixed with medication, it is one of the mind. Grace has been admitted to Rolling River Asylum and once she is gone, Rue's perfect world starts to crumble around her. Everything she has known is suddenly taken from her and with it her feeling of safety is dissolved.\nDesperate to pull Rue out of her depression, her brother talks her into going to a party at the Graph house, home to Johnathan Graph, a boy Rue has always felt a strong connection to, but never acted on it. Once she is at the party she reconnects with Johnathan and is shocked at how her feelings seem to be so strong for him, but with one touch Rue has a terrifying vision and it sets everything into motion.\nSoon after her revelation at the party, Grace and William suddenly disappear and with their absence two strangers, that of Joshua and Samantha Barrington, enter into Rue's life. They come as protectors, not only to her, but to everyone she loves. Without them she would be lost, but with them she is reminded of how much she does not know. There is a war coming, a war that threatens everything she loves, everything she knows or ever will know. She is forced to face the truth about herself and about her family's history, a truth that stems back to the beginning of time and that of the vampire.\nRewrite history through the eyes of the immortal.",
#   'format': 'Kindle Edition',
#   'authors': [{'author_id': '4529674', 'role': ''}],
#   'publisher': 'Vamptasy Publishing',
#   'num_pages': '2969',
#   'publication_day': '4',
#   'publication_month': '10',
#   'edition_information': 'Special Edition Boxed Set',
#   'publication_year': '2013',
#   'book_id': 18628483,
#   'ratings_count': '53',
#   'work_id': '41352626',
#   'title_without_series': 'The Blood and Light Series (Blood and Light #1-6)'},
#  {'text_reviews_count': '11',
#   'series': [],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': '',
#   'average_rating': '4.37',
#   'similar_books': [7775755,
#    9711714,
#    6369113,
#    10165727,
#    9165406,
#    8538112,
#    2856645,
#    18298890,
#    12458860,
#    10836471,
#    8159643,
#    13330305,
#    8526585,
#    10734210,
#    8901945,
#    8572163,
#    8299165,
#    2999495],
#   'description': "An unflinching, darkly funny, and deeply moving story of a boy, his seriously ill mother, and an unexpected monstrous visitor.\nAt seven minutes past midnight, thirteen-year-old Conor wakes to find a monster outside his bedroom window. But it isn't the monster Conor's been expecting-- he's been expecting the one from his nightmare, the nightmare he's had nearly every night since his mother started her treatments. The monster in his backyard is different. It's ancient. And wild. And it wants something from Conor. Something terrible and dangerous. It wants the truth. From the final idea of award-winning author Siobhan Dowd-- whose premature death from cancer prevented her from writing it herself-- Patrick Ness has spun a haunting and darkly funny novel of mischief, loss, and monsters both real and imagined.",
#   'format': 'Hardcover',
#   'authors': [{'author_id': '370361', 'role': ''}],
#   'publisher': 'Walker Childrens Hardbacks',
#   'num_pages': '240',
#   'publication_day': '1',
#   'publication_month': '11',
#   'edition_information': '',
#   'publication_year': '2012',
#   'book_id': 16693030,
#   'ratings_count': '49',
#   'work_id': '13492114',
#   'title_without_series': 'A Monster Calls'},
#  {'text_reviews_count': '2',
#   'series': [],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': '',
#   'average_rating': '2.52',
#   'similar_books': [19340876,
#    13576281,
#    18135491,
#    17885270,
#    17235685,
#    17972438,
#    9277954,
#    16108040,
#    3365911,
#    18880814,
#    2819356,
#    18187302,
#    18147856,
#    18663097,
#    18172178,
#    17405963,
#    15749995,
#    18579434],
#   'description': 'Justin Kairo, a young man coming of age, is searching for his own identity. He cannot find his place in the world until he accepts his own magical powers and embraces his destiny as a warlock.',
#   'format': 'ebook',
#   'authors': [{'author_id': '7151691', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '2013',
#   'book_id': 18134258,
#   'ratings_count': '2',
#   'work_id': '25473552',
#   'title_without_series': 'Erotic Diaries of a Warlock: Book 1 of 3'},
#  {'text_reviews_count': '7',
#   'series': [],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': 'B00S7S19LG',
#   'average_rating': '3.58',
#   'similar_books': [],
#   'description': '',
#   'format': '',
#   'authors': [{'author_id': '12020074', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 24494834,
#   'ratings_count': '36',
#   'work_id': '44090263',
#   'title_without_series': 'The Mate That Got Away'},
#  {'text_reviews_count': '1',
#   'series': ['150778'],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': 'B005681R0S',
#   'average_rating': '3.92',
#   'similar_books': [84066, 1295074],
#   'description': '',
#   'format': '',
#   'authors': [{'author_id': '50873', 'role': ''},
#    {'author_id': '232533', 'role': 'Ubersetzer'}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 12182388,
#   'ratings_count': '4',
#   'work_id': '589761',
#   'title_without_series': 'The Possessed (Dark Visions, #2)'},
#  {'text_reviews_count': '1',
#   'series': ['622710'],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '4.06',
#   'similar_books': [38673,
#    99111,
#    543164,
#    10147,
#    179639,
#    79549,
#    20413,
#    42329,
#    41684,
#    97089,
#    31244,
#    19337,
#    27712,
#    117930,
#    163716,
#    120711],
#   'description': 'By falling down a rabbit hole and stepping through a mirror, Alice experiences unusual adventures with a variety of nonsensical characters.',
#   'format': '',
#   'authors': [{'author_id': '8164', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 25896980,
#   'ratings_count': '4',
#   'work_id': '2375385',
#   'title_without_series': "Alice's adventures in Wonderland ; and, Through the looking-glass"},
#  {'text_reviews_count': '2',
#   'series': ['170205'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': 'B009CEYJMK',
#   'average_rating': '3.90',
#   'similar_books': [443679,
#    18518138,
#    13590694,
#    13981,
#    937727,
#    6479829,
#    385487,
#    274955,
#    12910647,
#    25791216,
#    8541031,
#    1290767,
#    2781816,
#    13643021],
#   'description': 'What would happen if a star writer went back to the darker themes of the original fairy tales for plots, and then crossed the Disney princesses with Charlie\'s Angels? What he\'d end up with is The Mermaid\'s Madness--a whole new take on The Little Mermaid. And with Jim C. Hines, of Jig the Goblin fame, penning the tale, you can bet it won\'t be "They lived happily ever after."\n11 hrs and 53 mins\n(c)2009 Jim C. Hines (P)2012 Audible, Inc.',
#   'format': 'Audiobook',
#   'authors': [{'author_id': '172490', 'role': ''},
#    {'author_id': '2490272', 'role': 'Narrator'}],
#   'publisher': 'Audible Frontiers',
#   'num_pages': '',
#   'publication_day': '18',
#   'publication_month': '9',
#   'edition_information': 'Unabridged',
#   'publication_year': '2012',
#   'book_id': 16037540,
#   'ratings_count': '3',
#   'work_id': '6519338',
#   'title_without_series': 'The Mermaid’s Madness'},
#  {'text_reviews_count': '9',
#   'series': ['177745'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': 'B00U3M5ZAA',
#   'average_rating': '3.73',
#   'similar_books': [5769327,
#    7120376,
#    7141788,
#    8301228,
#    832981,
#    27412086,
#    12258599,
#    5962367,
#    9591244,
#    31349708,
#    22067388,
#    9048370,
#    6265780,
#    6397961],
#   'description': "A prank gone wrong throws three unlikely partners together: A demon. A dragon. And an egg.\nIn the ordinary world, forces are at work which keep the balance of the universe in order. Enter Eve Sinclair, a higher demon with a mission--to sway those souls on the brink of Decision, to push them toward hell.\nAfter a prank played by her brothers, Eve finds herself holding the proverbial bag, accused of stealing a precious dragon egg. Worse, it's a royal egg, as she learns from Ranton, the furious commander of the dragon legion.\nNot a creature to have on one's bad side, Ranton shifts between his human and dragon forms, keeping Eve off-balance and off her game. Normally a master at manipulating males, Eve finds that Ranton is more than a match for her...as is his brother, the new dragon king. In their arms, she's mere putty.\nAnd soon they're not only molding her desires, but her heart.\nWarning, this title contains the following: explicit sex, graphic language, menage a troi, and steamy dragon love.\nNote: This book is a re-release of a previous edition.",
#   'format': '',
#   'authors': [{'author_id': '263567', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 25162658,
#   'ratings_count': '79',
#   'work_id': '13276491',
#   'title_without_series': "The Dragons' Demon: A Dragon's Dream (Ethereal Foes, #1)"},
#  {'text_reviews_count': '3',
#   'series': ['159489'],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '4.36',
#   'similar_books': [3471257,
#    2054617,
#    1128399,
#    1127545,
#    2373909,
#    1451628,
#    2108205,
#    6473945],
#   'description': "The Wizards Guild has been shattered by a coup and, in the uproar, Geralt was seriously injured. The Witcher is supposed to be a guardian of the innocent, a protector of those in need, a defender against powerful and dangerous monsters that prey on men in dark times.\nBut now that dark times have fallen upon the world, Geralt is helpless until he has recovered from his injuries.\nWhile war rages across all of the lands, the future of magic is under threat and those sorcerers who survive are determined to protect it. It's an impossible situation in which to find one girl - Ciri, the heiress to the throne of Cintra, has vanished - until a rumor places her in the Niflgaard court, preparing to marry the Emperor.\nInjured or not, Geralt has a rescue mission on his hands.\nThis is the third of the Witcher novels by Andrzej Sapkowski.",
#   'format': 'ebook',
#   'authors': [{'author_id': '38569', 'role': ''}],
#   'publisher': 'Orbit',
#   'num_pages': '288',
#   'publication_day': '24',
#   'publication_month': '6',
#   'edition_information': '',
#   'publication_year': '2014',
#   'book_id': 18656391,
#   'ratings_count': '13',
#   'work_id': '1877750',
#   'title_without_series': 'Baptism of Fire'},
#  {'text_reviews_count': '7',
#   'series': ['158860', '1100745'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': '',
#   'average_rating': '3.88',
#   'similar_books': [3311228,
#    913719,
#    826885,
#    83169,
#    1074893,
#    239252,
#    1161498,
#    286271,
#    530748,
#    107284,
#    1719304,
#    409796,
#    1515142,
#    301393,
#    898839,
#    722035],
#   'description': "In 1888 Lord and Lady Clayton sail from England but to West Africa and perish on a remote island. When their infant son is adopted by fanged, great anthropoid apes, he is Tarzan of the Apes. His intelligence and caring mother raise him to be king. Self-educated by his parents' library, Tarzan rescues genteel Jane Porter from the perils of his jungle.",
#   'format': 'Paperback',
#   'authors': [{'author_id': '10885', 'role': ''}],
#   'publisher': 'Ballantine Books',
#   'num_pages': '245',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 828189,
#   'ratings_count': '64',
#   'work_id': '1774048',
#   'title_without_series': 'Tarzan of the Apes (Tarzan, #1)'},
#  {'text_reviews_count': '2',
#   'series': ['961310'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': 'B01H9968QO',
#   'average_rating': '4.33',
#   'similar_books': [],
#   'description': "Glyn, former bodyguard and companion to a dragon lord, is now Lady Glynnes Janaleigh, a dragon lord in her own right. And she has found her intended mate. But, her new-found happiness is fleeting. Finding your mate is only half the battle. Keeping them alive is the other.\nFor a dragshi, duty is more than administering justice or saving the innocent. More than one suitor has fallen from the sky during a mating flight. Even worse, fate decrees mating fights don't always involve the partner you want.\nVengeance takes many paths. The leader called the Parant means to have his, no matter how long it takes or how many innocents die in the attempt. For the last two unattached dragon shifters, their only weapons to survive their destinies are their swords--and love. Sometimes not even dragon fire and talons are enough to overcome the mind control wielded by the leader called--the Parant.\nBook Four of the Dragshi Chronicles continues the tale of the dragshi, a human who can exchange bodies with a dragon. But the freedom of the skies comes with a price.\nAlthough the stories in the Dragshi Chronicles are connected, each book stands alone as an individual read",
#   'format': '',
#   'authors': [{'author_id': '777491', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 31124999,
#   'ratings_count': '3',
#   'work_id': '51738022',
#   'title_without_series': "Hatchling's Vengeance (Dragshi Chronicles #4)"},
#  {'text_reviews_count': '74',
#   'series': [],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '4.05',
#   'similar_books': [17544,
#    9442983,
#    13586799,
#    1755629,
#    679499,
#    15802651,
#    329873,
#    227241,
#    1354077,
#    1132614,
#    875078,
#    375108,
#    237347,
#    7165537,
#    1554931,
#    900274,
#    754690],
#   'description': '',
#   'format': 'Hardcover',
#   'authors': [{'author_id': '238787', 'role': ''}],
#   'publisher': 'Avery Publishing Group',
#   'num_pages': '80',
#   'publication_day': '1',
#   'publication_month': '11',
#   'edition_information': '',
#   'publication_year': '1996',
#   'book_id': 1488663,
#   'ratings_count': '226',
#   'work_id': '1479886',
#   'title_without_series': "The Greatest Gift: The Original Story That Inspired the Christmas Classic It's a Wonderful Life"},
#  {'text_reviews_count': '17',
#   'series': ['906272', '920128'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': 'B01HOYA9BO',
#   'average_rating': '4.06',
#   'similar_books': [22237392,
#    25543888,
#    21874620,
#    27232711,
#    22419535,
#    18807542,
#    18324027,
#    36266789,
#    16281505,
#    22751369,
#    22058895,
#    18653408,
#    15770300,
#    24905116,
#    19259981,
#    28006416,
#    82213,
#    25349279],
#   'description': "Previously published in Death's Excellent Vacation anthology and Magic Graves collection.\nAn exciting novelette set in Jeaniene Frost's Night Huntress world\nA romantic getaway for vampires Cat Crawfield and her husband Bones is cut short when they're called on to guard a spoiled heiress with a price on her head, and an undead hitman on her trail.\nWhat starts as a simple bodyguard job ends up being a fight for survival that neither Cat, nor Bones saw coming.",
#   'format': '',
#   'authors': [{'author_id': '669810', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 30807926,
#   'ratings_count': '190',
#   'work_id': '48079251',
#   'title_without_series': 'One for the Money (Night Huntress #4.5)'},
#  {'text_reviews_count': '12',
#   'series': ['937868'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': '',
#   'average_rating': '3.99',
#   'similar_books': [],
#   'description': 'Asian-American superheroines Evie Tanaka and Aveda Jupiter protect San Francisco from perilous threats in the second book in Sarah Kuhn\'s snarky and smart fantasy trilogy * "The superheroine we\'ve been waiting for." --Seanan McGuire\nOnce upon a time, Aveda Jupiter (aka Annie Chang) was demon-infested San Francisco\'s most beloved superheroine, a beacon of hope and strength and really awesome outfits. But all that changed the day she agreed to share the spotlight with her best friend and former assistant Evie Tanaka--who\'s now a badass, fire-wielding superheroine in her own right. They were supposed to be a dynamic duo, but more and more, Aveda finds herself shoved into the sidekick role. Where, it must be said, she is not at all comfortable.\nIt doesn\'t help that Aveda\'s finally being forced to deal with fallout from her diva behavior--and the fact that she\'s been a less than stellar friend to Evie. Or that Scott Cameron--the man Aveda\'s loved for nearly a decade--is suddenly giving her the cold shoulder after what seemed to be some promising steps toward friendship. Or that the city has been demon-free for three months in the wake of Evie and Aveda\'s apocalypse-preventing battle against the evil forces of the Otherworld, leaving Aveda without the one thing she craves most in life: a mission.\nAll of this is causing Aveda\'s burning sense of heroic purpose--the thing that\'s guided her all these years--to falter.\nIn short, Aveda Jupiter is having an identity crisis.\nWhen Evie gets engaged and drafts Aveda as her maid-of-honor, Aveda finally sees a chance to reclaim her sense of self and sets out on a single-minded mission to make sure Evie has the most epic wedding ever. But when a mysterious, unseen supernatural evil rises up and starts attacking brides-to-be, Aveda must summon both her superheroine and best friend mojo to take down the enemy and make sure Evie\'s wedding goes off without a hitch--or see both her city and her most important friendship destroyed forever.',
#   'format': 'Paperback',
#   'authors': [{'author_id': '612167', 'role': ''}],
#   'publisher': 'Daw Books',
#   'num_pages': '384',
#   'publication_day': '4',
#   'publication_month': '7',
#   'edition_information': '',
#   'publication_year': '2017',
#   'book_id': 32970513,
#   'ratings_count': '32',
#   'work_id': '51571778',
#   'title_without_series': 'Heroine Worship (Heroine Complex, #2)'},
#  {'text_reviews_count': '1',
#   'series': ['181470', '779747'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': '',
#   'average_rating': '4.01',
#   'similar_books': [68843,
#    208161,
#    101991,
#    11555,
#    973196,
#    6903495,
#    2452401,
#    363014,
#    446813,
#    399477,
#    155977,
#    463057,
#    34871,
#    1527531,
#    179734,
#    293098,
#    219635,
#    543154],
#   'description': 'Volume One of Clive Barker\'s seminal Books of Bloodcontains the stories: \'The Book of Blood\', \'The Midnight Meat Train\', \'The Yattering and Jack\', \'Pig Blood Blues\', \'Sex, Death and Starshine\', \'In the Hills, the Cities\'.\nWith the 1984 publication of Books of Blood, Clive Barker became an overnight literary sensation. He was hailed by Stephen King as "the future of horror", and won both the British and World Fantasy Awards. Now, with his numerous bestsellers, graphic novels, and hit movies like the Hellraiser, Clive Barker has become an industry unto himself. But it all started here, with this tour de force collection that rivals the dark masterpieces of Edgar Allan Poe. Read him and rediscover the true meaning of fear.',
#   'format': 'ebook',
#   'authors': [{'author_id': '10366', 'role': ''}],
#   'publisher': 'Little, Brown Book Group',
#   'num_pages': '213',
#   'publication_day': '26',
#   'publication_month': '10',
#   'edition_information': '',
#   'publication_year': '2015',
#   'book_id': 30340820,
#   'ratings_count': '3',
#   'work_id': '1249260',
#   'title_without_series': 'Books of Blood 1 (Books of Blood #1)'},
#  {'text_reviews_count': '61',
#   'series': [],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '3.81',
#   'similar_books': [114555,
#    219231,
#    455901,
#    102888,
#    6421529,
#    121607,
#    135289,
#    57070,
#    1419203,
#    127263,
#    378366,
#    1659076,
#    670372,
#    139994,
#    753136,
#    349734,
#    215647,
#    622100],
#   'description': 'The "magic" that once was America died horribly along with most of the Earth\'s inhabitants when an asteroid crashed into the planet sometime during the twenty-first century. Hundreds of years have passed, and all that remains of the time before are fragmented memories distorted by superstition -- as a tragically reduced populace suffers greatly under the tyranny of a repressive ruling order. But destiny has chosen Disme Latimer to lead a wasted world out of the darkness ... with a book. Written by a courageous scientist ancestor, it is a sacred, unsettling tome rife with disturbing ideas and revelations ... and an impossible hope that compels a gentle, troubled young woman to abandon her abusive home in search of truth and her true self. But common "wisdom" and lore warn of grave dangers out in the world. Evil is there, a malevolence beyond imagining. And in the depths of the Earth, a gargantuan beast asleep for centuries has begun to stir ...',
#   'format': 'Paperback',
#   'authors': [{'author_id': '20560', 'role': ''}],
#   'publisher': 'Harper Voyager',
#   'num_pages': '512',
#   'publication_day': '29',
#   'publication_month': '4',
#   'edition_information': '',
#   'publication_year': '2003',
#   'book_id': 89588,
#   'ratings_count': '1480',
#   'work_id': '822875',
#   'title_without_series': 'The Visitor'},
#  {'text_reviews_count': '2',
#   'series': [],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '3.08',
#   'similar_books': [],
#   'description': 'Prinsessakaksoset Armada ja Elena on erotettu heti syntymastaan. He eivat missaan tapauksessa saa olla tekemisissa keskenaan ensimmaisten 13 elinvuotensa aikana, ettei kauhea ennustus toteutuisi. Niinpa tytot ovat elelleet omaa elamaansa toisistaan tietamatta - Armada kuningasparin kanssa Tahtilinnan valtakunnassa ja Elena kaukana, kaukana Suomessa, Pernaisten tuppukylassa isoaitinsa kanssa. Vaan saman tien kun totuus lipsahtaa Armadan korviin, han odottaa etta jaa yksin linnaan ja malttamattomana ja mokomaa naurettavaa ennustusta uhmaten kutsuu Elenan luokseen.\nSisarukset ovat ulkonakoa lukuun ottamatta varsin erilaiset mutta loytavat silti nopeasti sielunkumppanuuden. Linna ilman aikuisten valvontaa tarjoaa tytoille unelmien temmellyskentan, ja linnan riemunkirjava asujaimisto tulee Elenalle tutuksi: minijattilaiset, iikkiaiset, allorulliaiset, heggo-hegot, tsontut ynna muut. Osaan olisi parempi olla tormaamatta iltapimealla! Riemukas yhdessaolo alkaa kuitenkin pian saada pahaenteisia piirteita, silla tyttojen maaginen 13-vuotispaiva on tulollaan... Mita on tuo hiuksianostattava jyrina linnan alta?',
#   'format': 'Hardcover',
#   'authors': [{'author_id': '6150407', 'role': ''}],
#   'publisher': 'Karisto',
#   'num_pages': '405',
#   'publication_day': '',
#   'publication_month': '3',
#   'edition_information': '',
#   'publication_year': '2011',
#   'book_id': 15861987,
#   'ratings_count': '12',
#   'work_id': '21611806',
#   'title_without_series': 'Ennustus (Tähtisilmät, #1)'},
#  {'text_reviews_count': '58',
#   'series': [],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '3.75',
#   'similar_books': [673024,
#    6747831,
#    6056679,
#    121611,
#    651807,
#    869239,
#    1369365,
#    116568,
#    270492,
#    426207,
#    68339],
#   'description': "It was many years ago that humans came and settled the world of Newholme-cruelly bending the planet to their will; setting down roots and raising up cities and farms and a grand temple to their goddess.But now the ground itself is shaking with ever-increasing violence. And the Great Questioner, official arbiter of the Council of Worlds, has come to this isolated orb to investigate rumors of a terrible secret that lies buried deep within Newholme's past--a past that is not dead, not completely. And it will fall to Mouche, a beautiful youth of uncommon cleverness and spirit, to save his imperiled home by dicovering and embracing that which makes him unique among humans. For every living thing on newholme is doomed, unless Mouche can appease something dark and terrible that is coiled within...and surrender to the mysterious ecstatic revelry taht results when the six moons join.",
#   'format': 'Paperback',
#   'authors': [{'author_id': '20560', 'role': ''}],
#   'publisher': 'Harper Voyager',
#   'num_pages': '544',
#   'publication_day': '6',
#   'publication_month': '4',
#   'edition_information': '',
#   'publication_year': '1999',
#   'book_id': 89583,
#   'ratings_count': '1321',
#   'work_id': '86460',
#   'title_without_series': 'Six Moon Dance'},
#  {'text_reviews_count': '15',
#   'series': ['176328'],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '3.89',
#   'similar_books': [9536651,
#    9671126,
#    9553503,
#    9395215,
#    9666812,
#    9300960,
#    6368611,
#    7817785,
#    9642278,
#    12812657,
#    9720766,
#    6798947,
#    6740756,
#    8724084,
#    8662410,
#    9918110,
#    8130839,
#    10637766],
#   'description': "Luce would die for Daniel.\nAnd she has. Over and over again. Throughout time, Luce and Daniel have found each other, only to be painfully torn apart: Luce dead, Daniel left broken and alone. But perhaps it doesn't need to be that way. . . .\nLuce is certain that something--or someone--in a past life can help her in her present one. So she begins the most important journey of this lifetime . . . going back eternities to witness firsthand her romances with Daniel . . . and finally unlock the key to making their love last.\nCam and the legions of angels and Outcasts are desperate to catch Luce, but none are as frantic as Daniel. He chases Luce through their shared pasts, terrified of what might happen if she rewrites history.\nBecause their romance for the ages could go up in flames . . . forever.\nSweeping across centuries, PASSION is the third novel in the unforgettably epic FALLEN series.\nFrom the Hardcover edition.",
#   'format': 'Audio',
#   'authors': [{'author_id': '2905297', 'role': ''},
#    {'author_id': '1144378', 'role': ''}],
#   'publisher': 'Listening Library (Audio)',
#   'num_pages': '0',
#   'publication_day': '14',
#   'publication_month': '6',
#   'edition_information': '',
#   'publication_year': '2011',
#   'book_id': 11890856,
#   'ratings_count': '138',
#   'work_id': '10958266',
#   'title_without_series': 'Passion (Fallen, #3)'},
#  {'text_reviews_count': '2',
#   'series': ['226926'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': '',
#   'average_rating': '4.05',
#   'similar_books': [11776110,
#    3171884,
#    3233199,
#    9617061,
#    6412809,
#    15927534,
#    13548434,
#    13561713,
#    6775781,
#    10974970,
#    13569400,
#    12306828,
#    7212421],
#   'description': 'She makes him feel more alive than he has since he died...\nChivalry is far from undead...\nMatthew Halkett, Earl of Blodswell, is one of the few men in the tonwho can claim to be a knight in shining armor--because that\'s precisely what he was before being turned into a vampyre. When he spies a damsel in distress in the midst of a storm in Hyde Park, his natural instinct is to rush to her aid...\nBut not every woman needs to be rescued...\nWeather-controlling witch Rhiannon Sinclair isn\'t caught in a storm-- she\'s the cause of it. She\'s mortified to have been caught making trouble by the imposing earl, but she doesn\'t need any man--never has, and is sure she never will...\nBut when Rhiannon encounters Matthew again, her powers go awry and his supernatural abilities run amok. Between the two of them, the tonis thrown into an uproar. There\'s never been a more tempestuous scandal...\nPraise for Lydia Dare:\n"Heartwarming romance, engaging characters, and engrossing plot twists...fast becoming \'must buy\' books. I recommend them all."\n-Star-Crossed Romance\nPraise for The Taming of the Wolf:\n"A truly satisfying read...Ms. Dare, I\'m ready for the next book please."\n-Once Upon a Romance"A compelling read that left me turning pages."\n-Fang-tastic Books\n"This series keeps getting better and better...flawless."\n-The Book Girl 5/5',
#   'format': 'ebook',
#   'authors': [{'author_id': '3112090', 'role': ''}],
#   'publisher': 'Sourcebooks Casablanca',
#   'num_pages': '368',
#   'publication_day': '1',
#   'publication_month': '7',
#   'edition_information': '',
#   'publication_year': '2011',
#   'book_id': 11890857,
#   'ratings_count': '12',
#   'work_id': '14521624',
#   'title_without_series': 'In the Heat of the Bite (Regency Vampyre Trilogy #2)'},
#  {'text_reviews_count': '7',
#   'series': ['522874'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': '',
#   'average_rating': '3.55',
#   'similar_books': [],
# ...
#   'format': 'Paperback',
#   'authors': [{'author_id': '4042181', 'role': ''}],
#   'publisher': 'Oxford University Press, USA',
#   'num_pages': '266',
#   'publication_day': '1',
#   'publication_month': '6',
#   'edition_information': '',
#   'publication_year': '2012',
#   'book_id': 12772759,
#   'ratings_count': '103',
#   'work_id': '41470919',
#   'title_without_series': 'Stealing Phoenix (Benedict, #2)'},
#  {'text_reviews_count': '48',
#   'series': ['169093', '212867', '169094'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': '',
#   'average_rating': '4.21',
#   'similar_books': [401434,
#    2386455,
#    437785,
#    2443516,
#    274416,
#    181494,
#    91965,
#    558681,
#    74271,
#    2272111,
#    1937398],
#   'description': 'Majestic and sweeping, Ship of Destiny concludes the tale of the Vestrit family and their part in the history of The Liveship Traders with a soaring and triumphant finale to this unique series of epic fantasy.',
#   'format': 'Paperback',
#   'authors': [{'author_id': '25307', 'role': ''}],
#   'publisher': 'Voyager',
#   'num_pages': '903',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '2001',
#   'book_id': 395953,
#   'ratings_count': '576',
#   'work_id': '2501194',
#   'title_without_series': 'Ship of Destiny (Liveship Traders, #3)'},
#  {'text_reviews_count': '2',
#   'series': ['181750', '241883'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': '',
#   'average_rating': '4.00',
#   'similar_books': [978772,
#    16908,
#    2330,
#    61660,
#    23606,
#    286363,
#    92016,
#    19297,
#    92023,
#    855741,
#    2334,
#    92003,
#    214180,
#    23662,
#    76834,
#    50001,
#    938210,
#    491075],
#   'description': "Gathered by Tolkien's son, this book features early versions of the first tales, a chronology of the events in Beleriand, the first Silmarillion map, and the only known description of the physical nature of Middle-earth's universe. An indispensable work of reference for fans--a dazzling introduction for new readers.",
#   'format': 'Hardcover',
#   'authors': [{'author_id': '656983', 'role': ''},
#    {'author_id': '9533', 'role': 'Editor'}],
#   'publisher': 'George Allen & Unwin',
#   'num_pages': '380',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': 'First Edition',
#   'publication_year': '1986',
#   'book_id': 4653649,
#   'ratings_count': '13',
#   'work_id': '2964236',
#   'title_without_series': 'The Shaping of Middle-earth (The History of Middle-Earth, #4)'},
#  {'text_reviews_count': '10',
#   'series': [],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': '',
#   'average_rating': '4.19',
#   'similar_books': [785762,
#    891218,
#    941468,
#    1214365,
#    1262455,
#    860954,
#    146686,
#    474411,
#    291257,
#    377661,
#    1238371,
#    82323,
#    1405670,
#    544707,
#    75586,
#    128202,
#    1191412,
#    629338],
#   'description': 'In a land ruled by war and love and strange enchantments, Cuchulain -- torn between gentleness and violence, haunted by the croakings of a sinister raven -- fights for his honor and his homeland and discovers too late the trap that the gods have set for him in the fatal beauty of Deirdre and the brutal jealousy of King Conor.',
#   'format': 'Paperback',
#   'authors': [{'author_id': '24183', 'role': ''}],
#   'publisher': 'Mandarin',
#   'num_pages': '511',
#   'publication_day': '31',
#   'publication_month': '1',
#   'edition_information': '',
#   'publication_year': '1991',
#   'book_id': 395955,
#   'ratings_count': '85',
#   'work_id': '827083',
#   'title_without_series': "On Raven's Wing"},
#  {'text_reviews_count': '3',
#   'series': ['199648'],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '3.78',
#   'similar_books': [9536651,
#    8259397,
#    9642278,
#    8288918,
#    9597831,
#    8171984,
#    11514121,
#    11319430,
#    10211811,
#    7264409,
#    9702149,
#    8686026,
#    13249960,
#    9306028,
#    8835188,
#    9918110,
#    8567502,
#    9640042],
#   'description': "The end . . . or a new beginning?\nAs Ellie comes to grips with her destiny as the Elect One, her relationship with Michael grows tense. When she meets a mysterious boy named Rafe, things get even more complicated.\nYet the time has come for the Elect One to stand against the group of evil fallen angels who are bent on destroying the world. In order to face the immeasurable malevolence heading her way, Ellie tries to put her personal life aside. But she soon learns that whoever holds her heart also holds the key to mankind's salvation--or destruction. As the end days approach, Ellie is faced with an epic decision. Who does her heart really belong to? And is her love strong enough to save the world?",
#   'format': 'ebook',
#   'authors': [{'author_id': '222429', 'role': ''}],
#   'publisher': 'HarperTeen',
#   'num_pages': '304',
#   'publication_day': '28',
#   'publication_month': '6',
#   'edition_information': '',
#   'publication_year': '2011',
#   'book_id': 11250599,
#   'ratings_count': '9',
#   'work_id': '14347696',
#   'title_without_series': 'Eternity (Fallen Angel, #2)'},
#  {'text_reviews_count': '10',
#   'series': ['259856'],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '4.03',
#   'similar_books': [13552268,
#    16035941,
#    21945537,
#    13386738,
#    21530587,
#    12591638,
#    12173539,
#    23208476,
#    23295634,
#    18398495,
#    13026206,
#    13628930,
#    24980201,
#    23533956,
#    21417565,
#    18469087,
#    14116167,
#    22585543],
#   'description': "When the animal disease spreads from Terra to Earth, the Hunters are established on Earth, as well, and Liliths father is commander of Earths Hunters... reason enough for Lilith, a Hunter herself, to ignore the magnetic pull of the alpha male determined to have her for his mate.\nBut Lilith isn't quite human herself not since she was attacked by werewolves and shes always had a thing for tall, dark, and creepy.",
#   'format': 'Paperback',
#   'authors': [{'author_id': '1142428', 'role': ''}],
#   'publisher': 'New Concepts Publishing',
#   'num_pages': '201',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '2008',
#   'book_id': 4827995,
#   'ratings_count': '142',
#   'work_id': '4893158',
#   'title_without_series': 'Red (Lilith Mercury Werewolf Hunter, #1)'},
#  {'text_reviews_count': '37',
#   'series': [],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '4.01',
#   'similar_books': [10880532,
#    11938249,
#    13505839,
#    6632179,
#    11451305,
#    10817583,
#    11984788,
#    12922874,
#    18776543,
#    11861894,
#    85570,
#    8285655,
#    18842194,
#    6555025,
#    11713438,
#    15859585,
#    10046509,
#    520967],
#   'description': "Toonopolis is a cartoon city that is home to the thoughts and ideas of all sentient beings in the universe. As the center of the Tooniverse, it acts as an other-worldly rest stop for these creations. Gemini is a teenage human boy who is thrust into Toonopolis through his father's scientific research program. He loses part of himself in the process and immediately begins a quest to regain his lost memories with the help of his Tooniverse guide named Jimbob the Talking Eggplant. After an altercation with a mysterious Shadowy Figure, Gemini's mission is changed, and he begins a new quest to defeat Shadowy Figure and protect Toonopolis from his nefarious destruction. Along the way, he meets new friends, discovers just how diverse and strange Toonopolis is, and learns lessons about compassion, forgiveness, redemption, and being true to oneself.",
#   'format': 'Paperback',
#   'authors': [{'author_id': '4689769', 'role': ''},
#    {'author_id': '4852705', 'role': 'Illustrator'}],
#   'publisher': 'Portmanteau Press LLC',
#   'num_pages': '314',
#   'publication_day': '1',
#   'publication_month': '5',
#   'edition_information': '',
#   'publication_year': '2011',
#   'book_id': 11365223,
#   'ratings_count': '61',
#   'work_id': '15569572',
#   'title_without_series': 'Toonopolis: Gemini (Toonopolis Files, #1)'},
#  {'text_reviews_count': '30',
#   'series': ['709737', '732060'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': '',
#   'average_rating': '4.31',
#   'similar_books': [18241610,
#    25489422,
#    25861903,
#    30826826,
#    28588345,
#    27158739,
#    23989925,
#    30145666,
#    25985241,
#    22586830],
#   'description': "The epic conclusion to the New York Times bestselling I Am Number Four series!\nThe Mogadorian invasion has come to Earth, and they have all but won the battle for our planet. Their warships loom over our most populous cities--like New York City, Tokyo, Moscow, Beijing, and New Delhi--and no army will risk making a move against them. The Garde are all that stand in their way . . . but they are no longer alone in this fight. Human teens from across the globe, like John Smith's best friend, Sam Goode, have begun to develop Legacies of their own.\nThe Garde have always known there is power in numbers. If they can find these new allies and join forces with them, they just might be able to win this war. The time has come for the Garde to make their final stand.",
#   'format': 'Paperback',
#   'authors': [{'author_id': '3380908', 'role': ''}],
#   'publisher': 'Michael Joseph',
#   'num_pages': '348',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '2016',
#   'book_id': 30839584,
#   'ratings_count': '154',
#   'work_id': '43216974',
#   'title_without_series': 'United as One (Lorien Legacies, #7)'},
#  {'text_reviews_count': '90',
#   'series': [],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': '',
#   'average_rating': '3.66',
#   'similar_books': [9141341,
#    10213208,
#    10839173,
#    107012,
#    19543244,
#    207475,
#    785698,
#    609873,
#    178234,
#    1121760,
#    11242882,
#    9458232,
#    12989420,
#    12966867,
#    18737,
#    72469,
#    129352],
#   'description': 'YOU THINK YOU KNOW THE STORY\nFive friends go to a remote\ncabin in the woods.\nBad things happen.\nIf you think you know the story,\nthink again.\nOfficial Movie Novelization.',
#   'format': 'Mass Market Paperback',
#   'authors': [{'author_id': '59165', 'role': ''},
#    {'author_id': '18015', 'role': 'Creator'},
#    {'author_id': '116615', 'role': 'Creator'}],
#   'publisher': 'Titan Books',
#   'num_pages': '297',
#   'publication_day': '17',
#   'publication_month': '4',
#   'edition_information': '',
#   'publication_year': '2012',
#   'book_id': 7980210,
#   'ratings_count': '795',
#   'work_id': '12372771',
#   'title_without_series': 'The Cabin in the Woods: The Official Movie Novelization'},
#  {'text_reviews_count': '12',
#   'series': ['161815', '360398'],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': '',
#   'average_rating': '4.31',
#   'similar_books': [29133,
#    2056298,
#    735994,
#    13809,
#    89552,
#    394429,
#    469208,
#    7893824,
#    617505],
#   'description': "Britain's king of heroic fantasy continues his classic, bestselling Drenai saga.",
#   'format': 'Paperback',
#   'authors': [{'author_id': '11586', 'role': ''}],
#   'publisher': 'Little Brown and Company',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 849769,
#   'ratings_count': '198',
#   'work_id': '2337952',
#   'title_without_series': 'The First Chronicles of Druss the Legend (Drenai Tales, #6)'},
#  {'text_reviews_count': '14',
#   'series': ['882346'],
#   'country_code': 'US',
#   'language_code': 'eng',
#   'asin': 'B00SI02BAG',
#   'average_rating': '4.28',
#   'similar_books': [25255605,
#    17557764,
#    13721357,
#    25118721,
#    28179656,
#    25350122,
#    27775171,
#    8537082,
#    18215470,
#    22523234,
#    6058757,
#    17971485,
#    21471316,
#    28443835,
#    341707,
#    23011925,
#    11028498],
#   'description': 'Together for the first time in one volume--all four novels in the dark science fiction epic, the Morgaine Cycle.\nThe gates were relics of a lost era, a linked network of portals that the ruthless Qual empire used to span Time and Space. The Science Buereau has come to believe that sometime, somewhere in the unreachable past, someone has done the unthinkable and warped the very fabric of the universe using these gates. Now, it is up to Morgaine, a mysterious woman aided by a single warrior honor-bound to serve her, to travel from world to world sealing the ancient gates whose very existence threatens the integrity of all worlds...',
#   'format': '',
#   'authors': [{'author_id': '989968', 'role': ''}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 24713696,
#   'ratings_count': '152',
#   'work_id': '44222969',
#   'title_without_series': 'The Complete Morgaine (Morgaine Saga #1-4)'},
#  {'text_reviews_count': '44',
#   'series': ['169291'],
#   'country_code': 'US',
#   'language_code': 'en-GB',
#   'asin': 'B00728DYII',
#   'average_rating': '4.38',
#   'similar_books': [58894,
#    295107,
#    2146957,
#    1375896,
#    7826116,
#    2850734,
#    93724,
#    363388,
#    590325,
#    573918,
#    8113344,
#    2073686,
#    140138,
#    34290,
#    169871,
#    385742,
#    393145,
#    65110],
#   'description': "The Dursleys were so mean and hideous that summer that all Harry Potter wanted was to get back to the Hogwarts School for Witchcraft and Wizardry. But just as he's packing his bags, Harry receives a warning from a strange, impish creature named Dobby who says that if Harry Potter returns to Hogwarts, disaster will strike.\nAnd strike it does. For in Harry's second year at Hogwarts, fresh torments and horrors arise, including an outrageously stuck-up new professor, Gilderoy Lockheart, a spirit named Moaning Myrtle who haunts the girls' bathroom, and the unwanted attentions of Ron Weasley's younger sister, Ginny.\nBut each of these seem minor annoyances when the real trouble begins, and someone--or something--starts turning Hogwarts students to stone. Could it be Draco Malfoy, a more poisonous rival than ever? Could it possibly be Hagrid, whose mysterious past is finally told? Or could it be the one everyone at Hogwarts most suspects...Harry Potter himself.",
#   'format': 'Kindle Edition',
#   'authors': [{'author_id': '1077326', 'role': ''}],
#   'publisher': 'Pottermore Limited',
#   'num_pages': '251',
#   'publication_day': '27',
#   'publication_month': '3',
#   'edition_information': 'United Kingdom edition',
#   'publication_year': '2012',
#   'book_id': 13563648,
#   'ratings_count': '1221',
#   'work_id': '6231171',
#   'title_without_series': 'Harry Potter and the Chamber of Secrets (Harry Potter, #2)'},
#  {'text_reviews_count': '1',
#   'series': [],
#   'country_code': 'US',
#   'language_code': '',
#   'asin': 'B00E7HNBXA',
#   'average_rating': '3.88',
#   'similar_books': [],
#   'description': 'Drawing upon the original Christian legends that coalesced over centuries into the familiar, jolly form of Saint Nicholas, pulp fiction pioneer Seabury Quinn weaves a spellbinding new origin for this most beloved of children\'s icons in his classic novella Roads.\n"I have not tried to paint the portrait of a man, but merely to present a personality and hazard a guess as to the motivation that makes Santa Claus the wondrous figure he is -- a figure who more than any other exemplifies the beauty of selflessness." -- Seabury Quinn',
#   'format': '',
#   'authors': [{'author_id': '263531', 'role': ''},
#    {'author_id': '348643', 'role': 'Illustrator'}],
#   'publisher': '',
#   'num_pages': '',
#   'publication_day': '',
#   'publication_month': '',
#   'edition_information': '',
#   'publication_year': '',
#   'book_id': 19490219,
#   'ratings_count': '6',
#   'work_id': '458974',
#   'title_without_series': 'Roads: A Legend of Santa Claus'},
#  ...]

# %%
type(G.nodes)
# Out:
# networkx.classes.reportviews.NodeView

# %%
graph_nodes = pd.DataFrame(data=my_chart2['nodes'])

# %%
praph

# %%
alt.data_transformers.enable('json')
alt.Chart(graph_nodes).mark_circle().encode(
    alt.X('average_rating'),
    alt.Y('publication_year'),
    tooltip='title_without_series',
    size='num_pages'
)

# %%
pd.DataFrame(G.nodes).dtypes
